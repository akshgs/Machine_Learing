# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('/content/drive/MyDrive/data science/tip-amount_(2).xlsx')
df
# Out:
#    Meal  Observed total bill(xi)  Observed tip bill(yi)
# 0     1                       34                      5
# 1     2                      108                     17
# 2     3                       64                     11
# 3     4                       88                      8
# 4     5                       99                     14

# %%
y=df['Observed tip bill(yi)']
x=df.drop(['Observed tip bill(yi)','Meal'],axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)

# %%
x_test
# Out:
#    Observed total bill(xi)
# 1                      108

# %%
y_test
# Out:
# 1    17
# Name: Observed tip bill(yi), dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
model=rf.fit(x_train,y_train)

# %%
pre=model.predict(x_test)
print(pre)
# Out:
# [14]

# %%
x_test
# Out:
#    Observed total bill(xi)
# 1                      108

# %%
type(x_test)
# Out:
# pandas.core.frame.DataFrame

# %%
x=int(input('enter a value for predict'))
a=pd.Series(x)
df=pd.DataFrame(a)
prediction=model.predict(df)
print('tip amount is :',prediction)
# Out:
# enter a value for predict200
# tip amount is : [14]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

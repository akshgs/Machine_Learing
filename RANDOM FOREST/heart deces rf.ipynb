# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %%
df=pd.read_csv('/content/drive/MyDrive/data science/heart_2020_cleaned.csv')
df
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
df.head(10)
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
# 5          Yes  28.87     Yes              No     No             6.0
# 6           No  21.63      No              No     No            15.0
# 7           No  31.64     Yes              No     No             5.0
# 8           No  26.45      No              No     No             0.0
# 9           No  40.69      No              No     No             0.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race  \
# 0          30.0          No  Female        55-59  White
# 1           0.0          No  Female  80 or older  White
# ...

# %%
df.tail(10)
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 319785           No  31.93      No             Yes     No             0.0
# 319786          Yes  33.20     Yes              No     No             0.0
# 319787           No  36.54      No              No     No             7.0
# 319788           No  23.38      No              No     No             0.0
# 319789           No  22.22      No              No     No             0.0
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# 319785           0.0          No    Male        65-69  Hispanic       No
# ...

# %%
df.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
# ...

# %%
df.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean       28.325399         3.37171       3.898366       7.097075
# std         6.356100         7.95085       7.955235       1.436007
# min        12.020000         0.00000       0.000000       1.000000
# 25%        24.030000         0.00000       0.000000       6.000000
# 50%        27.340000         0.00000       0.000000       7.000000
# 75%        31.420000         2.00000       3.000000       8.000000
# max        94.850000        30.00000      30.000000      24.000000

# %%
df.isna().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
freqgraph=df.select_dtypes(include=['int32','int64','float'])
freqgraph.hist(figsize=(10,5))
plt.show()

# %%
df.drop(['Race','AgeCategory'],axis=1,inplace=True)

# %%
df['HeartDisease']=df['HeartDisease'].replace({'Yes':1,'No':0})

# %%
df['Smoking']=df['Smoking'].replace({'Yes':1,'No':0})

# %%
df['AlcoholDrinking']=df['AlcoholDrinking'].replace({'Yes':1,'No':0})

# %%
df['Stroke']=df['Stroke'].replace({'Yes':1,'No':0})

# %%
df['DiffWalking']=df['DiffWalking'].replace({'Yes':1,'No':0})

# %%
df['Sex']=df['Sex'].replace({'Male':1,'Female':0})

# %%
df['Diabetic']=df['Diabetic'].replace({'Yes':1,'No':0})

# %%
df['PhysicalActivity']=df['PhysicalActivity'].replace({'Yes':1,'No':0})

# %%
df['GenHealth'].unique()
# Out:
# array(['Very good', 'Fair', 'Good', 'Poor', 'Excellent'], dtype=object)

# %%
df['GenHealth']=df['GenHealth'].replace({'Good':1,'Very good':2,'Excellent':3,'Fair':0,'Poor':0.5})

# %%
df['Asthma']=df['Asthma'].replace({'Yes':1,'No':0})

# %%
df['KidneyDisease']=df['KidneyDisease'].replace({'Yes':1,'No':0})

# %%
df['SkinCancer']=df['SkinCancer'].replace({'Yes':1,'No':0})

# %%
df.dtypes
# Out:
# HeartDisease          int64
# BMI                 float64
# Smoking               int64
# AlcoholDrinking       int64
# Stroke                int64
# PhysicalHealth      float64
# MentalHealth        float64
# DiffWalking           int64
# Sex                   int64
# Diabetic             object
# PhysicalActivity      int64
# GenHealth           float64
# SleepTime           float64
# Asthma                int64
# KidneyDisease         int64
# SkinCancer            int64
# dtype: object

# %%
plt.boxplot(df['HeartDisease'])
plt.title('boxplot of HeartDisease')
plt.show()

# %%
q1=np.percentile(df['HeartDisease'],25,interpolation='midpoint')
q2=np.percentile(df['HeartDisease'],50,interpolation='midpoint')
q3=np.percentile(df['HeartDisease'],75,interpolation='midpoint')

print(q1)
print(q2)
print(q3)
# Out:
# 0.0
# 0.0
# 0.0
# <ipython-input-28-5be04c2d5251>:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q1=np.percentile(df['HeartDisease'],25,interpolation='midpoint')
# <ipython-input-28-5be04c2d5251>:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q2=np.percentile(df['HeartDisease'],50,interpolation='midpoint')
# <ipython-input-28-5be04c2d5251>:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# ...

# %%
plt.boxplot(df['BMI'])
plt.title('boxplot of BMI')
plt.show()

# %%
q1=np.percentile(df['BMI'],25,interpolation='midpoint')
q2=np.percentile(df['BMI'],50,interpolation='midpoint')
q3=np.percentile(df['BMI'],75,interpolation='midpoint')

print(q1)
print(q2)
print(q3)
# Out:
# 24.03
# 27.34
# 31.42
# <ipython-input-30-ae4ec7c132b1>:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q1=np.percentile(df['BMI'],25,interpolation='midpoint')
# <ipython-input-30-ae4ec7c132b1>:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q2=np.percentile(df['BMI'],50,interpolation='midpoint')
# <ipython-input-30-ae4ec7c132b1>:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# ...

# %%
df['BMI'].median()
# Out:
# 27.34

# %%
iqr=q3-q1
lower=q1-1.5*iqr
upper=q3+1.5*iqr
print(lower)
print(upper)
# Out:
# 12.945
# 42.505

# %%
out=[]
for x in df['BMI']:
  if((x>upper) or (x<lower)):
    out.append(x)

# %%
ind=df['BMI']>upper
a=df.loc[ind].index
a
# Out:
# Int64Index([    32,     57,     90,    105,    107,    136,    170,    171,
#                176,    228,
#             ...
#             319550, 319586, 319590, 319600, 319636, 319693, 319709, 319725,
#             319777, 319794],
#            dtype='int64', length=10351)

# %%
for i in a:
  df.drop([i],inplace=True)

# %%
plt.boxplot(df['BMI'])
plt.title('outlier removed of BMI')
plt.show()

# %%
plt.boxplot(df['PhysicalHealth'])
plt.title('boxplot of PhysicalHealth')
plt.show()

# %%
q1=np.percentile(df['PhysicalHealth'],25,interpolation='midpoint')
q2=np.percentile(df['PhysicalHealth'],50,interpolation='midpoint')
q3=np.percentile(df['PhysicalHealth'],75,interpolation='midpoint')

print(q1)
print(q2)
print(q3)

# %%
iqr=q3-q1
lower1=q1-1.5*iqr
upper1=q3+1.5*iqr
print(lower1)
print(upper1)

# %%
out1=[]
for x in df['PhysicalHealth']:
  if((x>upper1)) or ((x<lower1)):
    out1.append(x)
out1

# %%
ind1=df['PhysicalHealth']>upper1
a1=df.loc[ind1].index
a1

# %%
for j in a1:
  df.drop([j],inplace=True)

# %%
plt.boxplot(df['PhysicalHealth'])
plt.title('outlier removed boxplot of PhysicalHealth')
plt.show()

# %%
plt.boxplot(df['MentalHealth'])
plt.title('boxplot of MentalHealth')
plt.show()

# %%
q1=np.percentile(df['MentalHealth'],25,interpolation='midpoint')
q2=np.percentile(df['MentalHealth'],50,interpolation='midpoint')
q3=np.percentile(df['MentalHealth'],75,interpolation='midpoint')

print(q1)
print(q2)
print(q3)

# %%
iqr=q3-q1
lower2=q1-1.5*iqr
upper2=q3+1.5*iqr
print(lower2)
print(upper2)

# %%
out2=[]
for x in df['MentalHealth']:
  if((x>upper2)) or ((x<lower2)):
    out2.append(x)

# %%
ind2=df['MentalHealth']>upper2
a2=df.loc[ind2].index
a2

# %%
for j in a2:
  df.drop([j],inplace=True)

# %%
plt.boxplot(df['MentalHealth'])
plt.title('outlier removed')
plt.show()

# %%
plt.boxplot(df['SleepTime'])
plt.title('boxplot of GenHealth')
plt.show()

# %%
q1=np.percentile(df['SleepTime'],25,interpolation='midpoint')
q2=np.percentile(df['SleepTime'],50,interpolation='midpoint')
q3=np.percentile(df['SleepTime'],75,interpolation='midpoint')

print(q1)
print(q2)
print(q3)

# %%
iqr=q3-q1
lower3=q1-1.5*iqr
upper3=q3+1.5*iqr
print(lower3)
print(upper3)

# %%
out3=[]
for x in df['SleepTime']:
  if((x>upper3)) or ((x<lower3)):
    out3.append(x)

# %%
ind3=df['SleepTime']>upper3
a3=df.loc[ind3].index
a3

# %%
for j in a3:
  df.drop([j],inplace=True)

# %%
plt.boxplot(df['SleepTime'])
plt.title('boxplot of SleepTime')
plt.show()

# %%
y=df['HeartDisease']
x=df.drop(['HeartDisease'],axis=1)
a=df.drop(['Diabetic'],inplace=True,axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.25)

# %%
x_test

# %%
y_test

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
model=dt.fit(x_train,y_train)
pickle.dump(dt,open('model.pkl','wb'))

# %%
pre=model.predict(x_test)

# %%
print(y_test)

# %%
print(pre)

# %%
from sklearn.metrics import mean_squared_error
print('MSE is :',mean_squared_error(y_test,pre))

# %%
type(x)

# %%
x=int(input('enter your '))
